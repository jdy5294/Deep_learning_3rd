# %% [markdown]
# <a href="https://colab.research.google.com/github/jdy5294/Deep_learning_3rd/blob/master/JDY/CH05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5장. 선형 회귀 모델: 먼저 긋고 수정하기

# %% [markdown]
# ## 5-1. 텐서플로에서 실행하는 선형 회귀 모델

# %% [markdown]
# ### 1. 환경 준비

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ### 2. 데이터 준비

# %%
x = np.array([2, 4, 6, 8])
y = np.array([81, 93, 91, 97])

# %% [markdown]
# ### 3. 모델 실행

# %%
model = Sequential()

model.add(Dense(1, input_dim=1, activation='linear'))     # Dense(출력변수 개수, 입력변수 개수)

model.compile(optimizer='sgd', loss='mse')                # sgd: 경사하강법

model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 364ms/step - loss: 7799.2964
# Epoch 2/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 1979.4601
# Epoch 3/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 1119.3177
# Epoch 4/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 987.6650
# Epoch 5/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 963.0438
# Epoch 6/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 954.1768
# Epoch 7/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 947.6580
# Epoch 8/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 941.5177
# Epoch 9/2000
# 1/1 [==============================] - 0s 17ms/step - loss: 935.4666
# Epoch 10/2000
# 1/1 [==============================] - 0s 13ms/step - loss: 929.4620
# Epoch 11/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 923.4972
# Epoch 12/2000
# ...

# %% [markdown]
# ### 4. 그래프로 확인

# %%
plt.scatter(x, y)
plt.plot(x, model.predict(x),'r')
plt.show()
# Out:
# 1/1 [==============================] - 0s 78ms/step

# %% [markdown]
# ### 5. 모델 테스트

# %%
hour = 7
prediction = model.predict([hour])

print("%.f시간을 공부할 경우의 예상 점수는 %.02f점입니다" % (hour, prediction))
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 7시간을 공부할 경우의 예상 점수는 95.12점입니다

# %% [markdown]
# ## 5-2 텐서플로에서 실행하는 다중 선형 회귀 모델

# %% [markdown]
# ### 1. 모델 학습

# %%
x = np.array([[2, 0], [4, 4], [6, 2], [8, 3]])
y = np.array([81, 93, 91, 97])

model = Sequential()

model.add(Dense(1, input_dim=2, activation='linear'))
model.compile(optimizer='sgd' ,loss='mse')

model.fit(x, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 339ms/step - loss: 9456.3555
# Epoch 2/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 1520.8815
# Epoch 3/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 957.3571
# Epoch 4/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 912.3351
# Epoch 5/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 903.8136
# Epoch 6/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 897.8934
# Epoch 7/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 892.1896
# Epoch 8/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 886.5348
# Epoch 9/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 880.9170
# Epoch 10/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 875.3350
# Epoch 11/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 869.7882
# Epoch 12/2000
# ...

# %% [markdown]
# ### 2. 모델 테스트

# %%
hour = 7
private_class = 4
prediction = model.predict([[hour, private_class]])

print("%.f시간을 공부하고 %.f시간의 과외를 받을 경우, 예상 점수는 %.02f점입니다" % (hour, private_class, prediction))
# Out:
# 1/1 [==============================] - 0s 99ms/step
# 7시간을 공부하고 4시간의 과외를 받을 경우, 예상 점수는 97.53점입니다
